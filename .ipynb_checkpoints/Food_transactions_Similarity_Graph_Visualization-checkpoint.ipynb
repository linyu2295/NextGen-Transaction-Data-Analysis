# %% [markdown]
# # Similarity Graph Visualization
#
# ### Multidimensional scaling:
# - MDS is a useful way to visualize high-dimensional distance (or dissimilarity) matrix $D$ in a few - usually two - dimensions.
# - MDS is used to measure the dissimilarity between objects - in pairs - and then put the objects in a common space and represent a spatial configuration. In other words, it is a dimension reduction treatment to discover the underlying structure of distance measures between objects.
#
#
# ### Goal of MDS:
# - MDS is used to determine whether the distance matrix may be represented by a map or configuration in a small number of dimensions such that distances on the map reproduce, approximately, the original distance matrix.
# - Given the number of dimensions, k, the aim of MDS is to find a configuration in k dimensions such that the stress criterion used is minimized.
#
#
# ### Assessment the fit of MDS solution:
# - Stress: the measure of Goodness of the fit.
# - $stress = \sqrt{\frac{\sum (d_{ij} - \hat{d_{ij}})^2}{\sum d_{ij}^2}}$, where $\hat{d_{ij}}$ is predicted distance based on the MDS model and $d_{ij}$ is the element of distance matrix $D$.
# - Scree Plot: the stress against the number of dimensions: as the number of dimensions increases the stress decreases, but there is a tradeoff between improving fit and reducing the interpretability of the solution. ‘Elbow’ point
#
#
# ### Challenges:
# - We do not know how many dimensions would be necessary in order to reproduce, even approximately, the given distances between objects.
# - One of the prime objects of the analysis will be to discover whether such a representation is possible in a small number of dimensions.
# - It is possible that  a local minimum rather than the global minimum will be found when moving the points short distances in such a manner as to reduce the stress slightly on each iteration to improve the configuration.

# %%
import numpy as np
import pandas as pd
import re
import os

from collections import Counter
import csv
import time
import json
import glob

import seaborn as sns

from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity

from wordcloud import WordCloud
import matplotlib.pyplot as plt

from matplotlib.backends.backend_pdf import PdfPages

from sklearn import manifold  # multidimensional scaling

# %%
def return_max_index(corr_mat):
    res_max = {}
    for i, r in enumerate(corr_mat.index):
        tmp = corr_mat[r]
        tmp[r] = 0
        max_index = tmp.idxmax()
        res_max[r] = (max_index, tmp[max_index])
    return res_max

def return_max_column(corr_mat):
    res_max = {}
    for i, r in enumerate(corr_mat.index):
        tmp = corr_mat.loc[r]
        tmp[r] = 0
        max_index = tmp.idxmax()
        res_max[r] = (max_index, tmp[max_index])
    return res_max

def return_largest_n_column(m, n):
    corr_mat = m.copy()
    res_max = {}
    for i, r in enumerate(corr_mat.index):
        tmp = corr_mat.loc[r]
        tmp[r] = 0
        res_max[r] = tmp[sorted(range(len(tmp)), key=lambda k: tmp[k], reverse=True)[:n]].to_dict()
    return res_max

def return_smallest_n_column(m, n):
    corr_mat = m.copy()
    res_max = {}
    for i, r in enumerate(corr_mat.index):
        tmp = corr_mat.loc[r]
        tmp[r] = 0
        res_max[r] = tmp[sorted(range(len(tmp)), key=lambda k: tmp[k], reverse=False)[:n]].to_dict()
    return res_max

# %% [markdown]
# ### Read matrix data

# %%
parent_dir = '.'

filename_list = sorted(glob.glob("{}/Results_week_*".format(parent_dir)))
print(filename_list)

dates_range_list = [f.split('Results_week_')[1].split('_') for f in filename_list]
print(dates_range_list)


#create a dictionary for the months
monthDict = {'01':'Jan', '02':'Feb', '03':'Mar', '04':'Apr', '05':'May', '06':'Jun', 
             '07':'Jul', '08':'Aug', '09':'Sep', '10':'Oct', '11':'Nov', '12':'Dec'}


sim_mat_restaurant = {}
conf_mat_restaurant = {}

sim_mat_grocery = {}
conf_mat_grocery = {}

for filename in filename_list:
    print(filename)
    
    sim_mat_restaurant[filename] = pd.read_csv('{}/sim_mat_restaurant_all.csv'.format(filename), 
                                 index_col=0)
    conf_mat_restaurant[filename] = pd.read_csv('{}/conf_mat_restaurant_all.csv'.format(filename),
                                  index_col=0)
    print('Restaurant - similarity and confidence matrix:', sim_mat_restaurant[filename].shape,
         conf_mat_restaurant[filename].shape)
    
    sim_mat_grocery[filename] = pd.read_csv('{}/sim_mat_grocery_all.csv'.format(filename), 
                              index_col=0)
    conf_mat_grocery[filename] = pd.read_csv('{}/conf_mat_grocery_all.csv'.format(filename), 
                               index_col=0)
    print('Grocery - similarity and confidence matrix:', sim_mat_grocery[filename].shape,
         conf_mat_grocery[filename].shape, '\n')
# Out:
# ['./Results_week_20200713_20200719', './Results_week_20200805_20200811', './Results_week_20201010_20201016']
# [['20200713', '20200719'], ['20200805', '20200811'], ['20201010', '20201016']]
# ./Results_week_20200713_20200719
# Restaurant - similarity and confidence matrix: (29, 29) (30, 29)
# Grocery - similarity and confidence matrix: (33, 33) (34, 33)
#
# ./Results_week_20200805_20200811
# Restaurant - similarity and confidence matrix: (29, 29) (30, 29)
# Grocery - similarity and confidence matrix: (33, 33) (34, 33)
#
# ./Results_week_20201010_20201016
# Restaurant - similarity and confidence matrix: (32, 32) (33, 32)
# Grocery - similarity and confidence matrix: (33, 33) (34, 33)

# %%
print(json.dumps(return_largest_n_column(sim_mat_restaurant['./Results_week_20200713_20200719'], n=6), indent = 4))

# print(json.dumps(return_largest_n_column(conf_mat_restaurant, n=5), indent = 4))
# Out:
# {
#     "American Restaurants": {
#         "Burgers": 0.057930999999999996,
#         "Sandwiches": 0.031942,
#         "Mexican Restaurants": 0.029324,
#         "Pizza": 0.025729000000000002,
#         "Chinese Restaurants": 0.015631,
#         "Asian Restaurants": 0.013380000000000001
#     },
#     "Asian Restaurants": {
#         "Chinese Restaurants": 0.031426,
#         "Japanese Restaurants": 0.017411000000000003,
#         "Latin American Restaurants": 0.016184999999999998,
#         "Sushi": 0.014003,
#         "American Restaurants": 0.013380000000000001,
#         "Mexican Restaurants": 0.012773999999999999
#     },
#     "BBQ Restaurants": {
#         "Chinese Restaurants": 0.005184,
#         "Asian Restaurants": 0.005113,
#         "Seafood Restaurants": 0.004370000000000001,
#         "Japanese Restaurants": 0.003956,
#         "Thai Restaurants": 0.003118,
#         "Latin American Restaurants": 0.0029649999999999998
#     },
#     "Bakeries": {
#         "American Restaurants": 0.011249,
#         "Sandwiches": 0.010748,
#         "Coffee Shops": 0.010337,
#         "Mexican Restaurants": 0.010048,
#         "Cafes": 0.008915000000000001,
#         "Italian Restaurants": 0.007309
#     },
#     "Bar Food": {
#         "Italian Restaurants": 0.004219,
#         "American Restaurants": 0.004025,
#         "Asian Restaurants": 0.003872,
#         "Seafood Restaurants": 0.003699,
#         "Mexican Restaurants": 0.0035810000000000004,
#         "Sandwiches": 0.0034770000000000005
#     },
#     "British Restaurants": {
#         "Pubs": 0.002382,
#         "Ice Cream": 0.002093,
#         "Middle Eastern Restaurants": 0.001003,
#         "Indian Restaurants": 0.000204,
#         "BBQ Restaurants": 0.000132,
#         "Chinese Restaurants": 0.000103
#     },
#     "Burgers": {
#         "American Restaurants": 0.057930999999999996,
#         "Sandwiches": 0.021928,
#         "Mexican Restaurants": 0.015599000000000002,
#         "Pizza": 0.015022999999999998,
#         "Chinese Restaurants": 0.00905,
#         "Asian Restaurants": 0.008695
#     },
#     "Cafes": {
#         "Bakeries": 0.008915000000000001,
#         "Coffee Shops": 0.007492,
#         "Latin American Restaurants": 0.005309,
#         "Asian Restaurants": 0.004068,
#         "Mexican Restaurants": 0.004039,
#         "Seafood Restaurants": 0.003778
#     },
#     "Chinese Restaurants": {
#         "Asian Restaurants": 0.031426,
#         "American Restaurants": 0.015631,
#         "Mexican Restaurants": 0.01499,
#         "Japanese Restaurants": 0.013186000000000002,
#         "Indian Restaurants": 0.012506,
#         "Sushi": 0.01102
#     },
#     "Coffee Shops": {
#         "Bakeries": 0.010337,
#         "Cafes": 0.007492,
#         "Latin American Restaurants": 0.005875,
#         "Asian Restaurants": 0.005695,
#         "Mexican Restaurants": 0.005568,
#         "American Restaurants": 0.00472
#     },
#     "Diners": {
#         "Chinese Restaurants": 0.00209,
#         "Mexican Restaurants": 0.002082,
#         "American Restaurants": 0.001865,
#         "Burgers": 0.00164,
#         "Japanese Restaurants": 0.001611,
#         "Coffee Shops": 0.001588
#     },
#     "Greek Restaurants": {
#         "Mediterranean Restaurants": 0.00488,
#         "Middle Eastern Restaurants": 0.0046429999999999996,
#         "Latin American Restaurants": 0.00186,
#         "Bar Food": 0.001819,
#         "Italian Restaurants": 0.001772,
#         "Seafood Restaurants": 0.001702
#     },
#     "Ice Cream": {
#         "Pubs": 0.006101,
#         "British Restaurants": 0.002093,
#         "Diners": 0.0007570000000000001,
#         "Latin American Restaurants": 0.00061,
#         "Cafes": 0.000453,
#         "Middle Eastern Restaurants": 0.00042800000000000005
#     },
#     "Indian Restaurants": {
#         "Asian Restaurants": 0.012575,
#         "Chinese Restaurants": 0.012506,
#         "American Restaurants": 0.005435,
#         "Latin American Restaurants": 0.005308,
#         "Thai Restaurants": 0.004986,
#         "Middle Eastern Restaurants": 0.004729
#     },
#     "Italian Restaurants": {
#         "American Restaurants": 0.013361000000000001,
#         "Mexican Restaurants": 0.012565,
#         "Sandwiches": 0.011034,
#         "Asian Restaurants": 0.008198,
#         "Chinese Restaurants": 0.008191,
#         "Burgers": 0.007379999999999999
#     },
#     "Japanese Restaurants": {
#         "Sushi": 0.026199,
#         "Asian Restaurants": 0.017411000000000003,
#         "Chinese Restaurants": 0.013186000000000002,
#         "Seafood Restaurants": 0.011034,
#         "Thai Restaurants": 0.008569,
#         "Latin American Restaurants": 0.007606999999999999
#     },
#     "Korean Restaurants": {
#         "Diners": 0.001531,
#         "Japanese Restaurants": 0.0009460000000000001,
#         "Thai Restaurants": 0.0007769999999999999,
#         "Seafood Restaurants": 0.000663,
#         "Mediterranean Restaurants": 0.00065,
#         "BBQ Restaurants": 0.0006190000000000001
#     },
#     "Latin American Restaurants": {
#         "Asian Restaurants": 0.016184999999999998,
#         "Mexican Restaurants": 0.011186,
#         "Chinese Restaurants": 0.009359000000000001,
#         "Sushi": 0.007773,
#         "Japanese Restaurants": 0.007606999999999999,
#         "American Restaurants": 0.007281
#     },
#     "Mediterranean Restaurants": {
#         "Greek Restaurants": 0.00488,
#         "Middle Eastern Restaurants": 0.004705,
#         "Japanese Restaurants": 0.002752,
#         "Seafood Restaurants": 0.0026969999999999997,
#         "Sushi": 0.002496,
#         "Cafes": 0.00243
#     },
#     "Mexican Restaurants": {
#         "American Restaurants": 0.029324,
#         "Sandwiches": 0.019332,
#         "Burgers": 0.015599000000000002,
#         "Chinese Restaurants": 0.01499,
#         "Asian Restaurants": 0.012773999999999999,
#         "Italian Restaurants": 0.012565
#     },
#     "Middle Eastern Restaurants": {
#         "Indian Restaurants": 0.004729,
#         "Mediterranean Restaurants": 0.004705,
#         "Greek Restaurants": 0.0046429999999999996,
#         "Latin American Restaurants": 0.002329,
#         "Asian Restaurants": 0.002285,
#         "Japanese Restaurants": 0.0017829999999999999
#     },
#     "Pizza": {
#         "American Restaurants": 0.025729000000000002,
#         "Sandwiches": 0.017401,
#         "Burgers": 0.015022999999999998,
#         "Mexican Restaurants": 0.010844,
#         "Italian Restaurants": 0.007219,
#         "Chinese Restaurants": 0.005712
#     },
#     "Pubs": {
#         "Ice Cream": 0.006101,
#         "British Restaurants": 0.002382,
#         "Middle Eastern Restaurants": 0.000525,
#         "Vegetarian Restaurants": 0.00035499999999999996,
#         "Bar Food": 0.000262,
#         "BBQ Restaurants": 0.000261
#     },
#     "Sandwiches": {
#         "American Restaurants": 0.031942,
#         "Burgers": 0.021928,
#         "Mexican Restaurants": 0.019332,
#         "Pizza": 0.017401,
#         "Italian Restaurants": 0.011034,
#         "Bakeries": 0.010748
#     },
#     "Seafood Restaurants": {
#         "Japanese Restaurants": 0.011034,
#         "Sushi": 0.010166,
#         "Asian Restaurants": 0.008605,
#         "Chinese Restaurants": 0.0076370000000000006,
#         "Latin American Restaurants": 0.006249,
#         "Mexican Restaurants": 0.005883
#     },
#     "Steakhouse": {
#         "BBQ Restaurants": 0.0019579999999999997,
#         "Seafood Restaurants": 0.001916,
#         "American Restaurants": 0.001001,
#         "Italian Restaurants": 0.000995,
#         "Mexican Restaurants": 0.00088,
#         "Bakeries": 0.0008449999999999999
#     },
#     "Sushi": {
#         "Japanese Restaurants": 0.026199,
#         "Asian Restaurants": 0.014003,
#         "Chinese Restaurants": 0.01102,
#         "Seafood Restaurants": 0.010166,
#         "Latin American Restaurants": 0.007773,
#         "Mexican Restaurants": 0.007166
#     },
#     "Thai Restaurants": {
#         "Asian Restaurants": 0.010517,
#         "Chinese Restaurants": 0.009053,
#         "Japanese Restaurants": 0.008569,
#         "Sushi": 0.006823999999999999,
#         "Seafood Restaurants": 0.0050490000000000005,
#         "Indian Restaurants": 0.004986
#     },
#     "Vegetarian Restaurants": {
#         "Greek Restaurants": 0.0012230000000000001,
#         "Seafood Restaurants": 0.0007030000000000001,
#         "Indian Restaurants": 0.0005679999999999999,
#         "Diners": 0.000549,
#         "Thai Restaurants": 0.000538,
#         "Mediterranean Restaurants": 0.000531
#     }
# }

# %%
print(json.dumps(return_largest_n_column(sim_mat_grocery['./Results_week_20200713_20200719'], n=6), indent = 4))
# Out:
# {
#     "Bakery": {
#         "Fruits & Vegetables": 0.278832,
#         "Meat, Seafood & Eggs": 0.255819,
#         "Dairy Products": 0.230336,
#         "Snack Foods": 0.223221,
#         "Prepared Foods": 0.180135,
#         "Condiments & Sauces": 0.166752
#     },
#     "Beer & Liquor": {
#         "Tea & Infusions": 1.4999999999999999e-05,
#         "Seasonings & Spices": 5e-06,
#         "Dairy Products": 1e-06,
#         "Fruits & Vegetables": 1e-06,
#         "Meat, Seafood & Eggs": 1e-06,
#         "Snack Foods": 1e-06
#     },
#     "Candied & Chocolate Covered Fruit": {
#         "Food Gift Baskets": 0.001877,
#         "Hot Chocolate": 0.0013189999999999999,
#         "Tofu, Soy & Vegetarian Products": 0.0008880000000000001,
#         "Candy & Chocolate": 0.000628,
#         "Milk": 0.000621,
#         "Frozen Desserts & Novelties": 0.000597
#     },
#     "Candy & Chocolate": {
#         "Bakery": 0.1128,
#         "Snack Foods": 0.106959,
#         "Fruits & Vegetables": 0.10665699999999999,
#         "Meat, Seafood & Eggs": 0.106003,
#         "Dairy Products": 0.102459,
#         "Prepared Foods": 0.086952
#     },
#     "Coffee": {
#         "Dairy Products": 0.043913,
#         "Meat, Seafood & Eggs": 0.041819999999999996,
#         "Bakery": 0.04099,
#         "Fruits & Vegetables": 0.040654,
#         "Condiments & Sauces": 0.039095,
#         "Snack Foods": 0.038854
#     },
#     "Condiments & Sauces": {
#         "Fruits & Vegetables": 0.188334,
#         "Meat, Seafood & Eggs": 0.184343,
#         "Dairy Products": 0.174021,
#         "Bakery": 0.166752,
#         "Snack Foods": 0.157138,
#         "Prepared Foods": 0.128858
#     },
#     "Cooking & Baking Ingredients": {
#         "Fruits & Vegetables": 0.144975,
#         "Dairy Products": 0.137021,
#         "Meat, Seafood & Eggs": 0.13564400000000001,
#         "Bakery": 0.127504,
#         "Snack Foods": 0.12184400000000001,
#         "Condiments & Sauces": 0.117503
#     },
#     "Dairy Products": {
#         "Fruits & Vegetables": 0.292817,
#         "Meat, Seafood & Eggs": 0.257554,
#         "Bakery": 0.230336,
#         "Snack Foods": 0.213883,
#         "Condiments & Sauces": 0.174021,
#         "Prepared Foods": 0.168192
#     },
#     "Dips & Spreads": {
#         "Dairy Products": 0.106385,
#         "Fruits & Vegetables": 0.104216,
#         "Meat, Seafood & Eggs": 0.103797,
#         "Bakery": 0.103539,
#         "Snack Foods": 0.098737,
#         "Condiments & Sauces": 0.092934
#     },
#     "Food Gift Baskets": {
#         "Candied & Chocolate Covered Fruit": 0.001877,
#         "Nuts & Seeds": 0.000176,
#         "Milk": 0.000151,
#         "Juice": 0.000149,
#         "Dips & Spreads": 0.00013000000000000002,
#         "Frozen Desserts & Novelties": 0.000129
#     },
#     "Frozen Desserts & Novelties": {
#         "Bakery": 0.069786,
#         "Dairy Products": 0.066874,
#         "Meat, Seafood & Eggs": 0.066553,
#         "Fruits & Vegetables": 0.06389299999999999,
#         "Snack Foods": 0.062079999999999996,
#         "Milk": 0.060309
#     },
#     "Fruit Flavored Drinks": {
#         "Bakery": 0.048098,
#         "Snack Foods": 0.047927,
#         "Meat, Seafood & Eggs": 0.047862,
#         "Dairy Products": 0.047642000000000004,
#         "Condiments & Sauces": 0.044723,
#         "Juice": 0.044150999999999996
#     },
#     "Fruits & Vegetables": {
#         "Meat, Seafood & Eggs": 0.33119899999999997,
#         "Dairy Products": 0.292817,
#         "Bakery": 0.278832,
#         "Snack Foods": 0.253504,
#         "Prepared Foods": 0.199756,
#         "Condiments & Sauces": 0.188334
#     },
#     "Grains, Rice & Cereal": {
#         "Fruits & Vegetables": 0.118056,
#         "Dairy Products": 0.113926,
#         "Meat, Seafood & Eggs": 0.11324100000000001,
#         "Bakery": 0.11267200000000001,
#         "Snack Foods": 0.108571,
#         "Condiments & Sauces": 0.09705599999999999
#     },
#     "Hot Chocolate": {
#         "Tofu, Soy & Vegetarian Products": 0.001916,
#         "Juice": 0.0018629999999999999,
#         "Frozen Desserts & Novelties": 0.001773,
#         "Milk": 0.0017519999999999999,
#         "Candy & Chocolate": 0.001678,
#         "Coffee": 0.001467
#     },
#     "Juice": {
#         "Meat, Seafood & Eggs": 0.093533,
#         "Bakery": 0.092833,
#         "Fruits & Vegetables": 0.091311,
#         "Dairy Products": 0.091015,
#         "Snack Foods": 0.08541699999999999,
#         "Condiments & Sauces": 0.080065
#     },
#     "Meat, Seafood & Eggs": {
#         "Fruits & Vegetables": 0.33119899999999997,
#         "Dairy Products": 0.257554,
#         "Bakery": 0.255819,
#         "Snack Foods": 0.230754,
#         "Prepared Foods": 0.194163,
#         "Condiments & Sauces": 0.184343
#     },
#     "Milk": {
#         "Fruits & Vegetables": 0.129444,
#         "Meat, Seafood & Eggs": 0.128631,
#         "Bakery": 0.126931,
#         "Dairy Products": 0.125306,
#         "Snack Foods": 0.11040499999999999,
#         "Condiments & Sauces": 0.101566
#     },
#     "Non-Dairy Milk": {
#         "Grains, Rice & Cereal": 0.019697,
#         "Dips & Spreads": 0.019012,
#         "Dairy Products": 0.018411,
#         "Fruits & Vegetables": 0.018028,
#         "Cooking & Baking Ingredients": 0.017387,
#         "Condiments & Sauces": 0.016928
#     },
#     "Nuts & Seeds": {
#         "Dairy Products": 0.03876,
#         "Fruits & Vegetables": 0.037958,
#         "Cooking & Baking Ingredients": 0.035672,
#         "Meat, Seafood & Eggs": 0.035299000000000004,
#         "Condiments & Sauces": 0.035249,
#         "Bakery": 0.034299
#     },
#     "Pasta & Noodles": {
#         "Meat, Seafood & Eggs": 0.07837100000000001,
#         "Dairy Products": 0.077831,
#         "Bakery": 0.07688099999999999,
#         "Condiments & Sauces": 0.07635700000000001,
#         "Snack Foods": 0.074601,
#         "Fruits & Vegetables": 0.074147
#     },
#     "Powdered Beverage Mixes": {
#         "Fruit Flavored Drinks": 0.019087,
#         "Condiments & Sauces": 0.018308,
#         "Cooking & Baking Ingredients": 0.017735,
#         "Snack Foods": 0.01725,
#         "Soda": 0.017063,
#         "Pasta & Noodles": 0.016907
#     },
#     "Prepared Foods": {
#         "Fruits & Vegetables": 0.199756,
#         "Meat, Seafood & Eggs": 0.194163,
#         "Bakery": 0.180135,
#         "Dairy Products": 0.168192,
#         "Snack Foods": 0.167186,
#         "Condiments & Sauces": 0.128858
#     },
#     "Prepared Meals": {
#         "Hot Chocolate": 0.000144,
#         "Tofu, Soy & Vegetarian Products": 0.000117,
#         "Prepared Foods": 8.6e-05,
#         "Soda": 8.6e-05,
#         "Soups & Broths": 6.2e-05,
#         "Non-Dairy Milk": 6.1e-05
#     },
#     "Seasonings & Spices": {
#         "Fruits & Vegetables": 0.065901,
#         "Dairy Products": 0.06460199999999999,
#         "Cooking & Baking Ingredients": 0.063621,
#         "Condiments & Sauces": 0.063549,
#         "Meat, Seafood & Eggs": 0.063097,
#         "Bakery": 0.057740999999999994
#     },
#     "Snack Foods": {
#         "Fruits & Vegetables": 0.253504,
#         "Meat, Seafood & Eggs": 0.230754,
#         "Bakery": 0.223221,
#         "Dairy Products": 0.213883,
#         "Prepared Foods": 0.167186,
#         "Condiments & Sauces": 0.157138
#     },
#     "Soda": {
#         "Bakery": 0.09613200000000001,
#         "Snack Foods": 0.095934,
#         "Meat, Seafood & Eggs": 0.095807,
#         "Dairy Products": 0.091176,
#         "Fruits & Vegetables": 0.088271,
#         "Condiments & Sauces": 0.083186
#     },
#     "Soups & Broths": {
#         "Condiments & Sauces": 0.050417000000000003,
#         "Dairy Products": 0.05005,
#         "Meat, Seafood & Eggs": 0.049823,
#         "Bakery": 0.048043999999999996,
#         "Fruits & Vegetables": 0.047237,
#         "Snack Foods": 0.045272
#     },
#     "Sports & Energy Drinks": {
#         "Soda": 0.038623000000000005,
#         "Snack Foods": 0.038044,
#         "Bakery": 0.03517,
#         "Dairy Products": 0.034953,
#         "Water": 0.034285,
#         "Meat, Seafood & Eggs": 0.03427
#     },
#     "Tea & Infusions": {
#         "Dairy Products": 0.034169,
#         "Meat, Seafood & Eggs": 0.033327999999999997,
#         "Bakery": 0.033280000000000004,
#         "Condiments & Sauces": 0.032775,
#         "Fruits & Vegetables": 0.031991000000000006,
#         "Snack Foods": 0.031806
#     },
#     "Tofu, Soy & Vegetarian Products": {
#         "Non-Dairy Milk": 0.014703,
#         "Dips & Spreads": 0.006807,
#         "Nuts & Seeds": 0.006762000000000001,
#         "Frozen Desserts & Novelties": 0.006571,
#         "Juice": 0.006528,
#         "Grains, Rice & Cereal": 0.0062450000000000006
#     },
#     "Vinegar Drinks": {
#         "Seasonings & Spices": 0.000283,
#         "Tofu, Soy & Vegetarian Products": 0.000246,
#         "Tea & Infusions": 0.000231,
#         "Cooking & Baking Ingredients": 0.000206,
#         "Soups & Broths": 0.000195,
#         "Juice": 0.000193
#     },
#     "Water": {
#         "Meat, Seafood & Eggs": 0.07159700000000001,
#         "Dairy Products": 0.07097200000000001,
#         "Snack Foods": 0.068912,
#         "Bakery": 0.06865700000000001,
#         "Fruits & Vegetables": 0.06828300000000001,
#         "Condiments & Sauces": 0.064586
#     }
# }

# %% [markdown]
# # Manifold Learning:
# ## Multidimensional Scaling
#
# Normalization:
# - Global
# - Row-based
# - others

# %%
# ## Global normalization
def get_global_based_norm(df):
    m_norm = df.copy()
    np.fill_diagonal(m_norm.values, 0)
    m_norm = m_norm.applymap(lambda x: (x - m_norm.min().min())/(m_norm.max().max() - m_norm.min().min()))
    return m_norm


# Row-based normalization
def get_row_based_norm(df):
    m_norm = df.copy()

    np.fill_diagonal(m_norm.values, 0)

    for i in range(m_norm.shape[0]):
        m_norm.iloc[i] = ((m_norm.iloc[i] - m_norm.iloc[i].min())/(m_norm.iloc[i].max()-m_norm.iloc[i].min()))

    np.fill_diagonal(m_norm.values, 1)

    m_norm = (m_norm + m_norm.T)/2
   
    return m_norm

def return_dissimilarity(m):
    m_dis = np.zeros((m.shape[0], m.shape[1]))
    for i in range(m.shape[0]):
        for j in range(i+1, m.shape[1]):
            m_dis[i, j] = np.sqrt(2 - 2*m.values[i, j])
    
    m_dis = m_dis + m_dis.T
    m_dis = pd.DataFrame(m_dis, index=m.index, columns=m.columns)
    return m_dis

# %%
def get_dfc_norm(category):
    
    dfc = {}

    for filename in filename_list:
        tmp_month = monthDict[filename.split('2020')[1][:2]]
        if category == 'restaurant':
            tmp_df = sim_mat_restaurant[filename]
            dfc[tmp_month] = tmp_df
        if category == 'grocery':
            tmp_df = sim_mat_grocery[filename]
            dfc[tmp_month] = tmp_df
        print(tmp_month, dfc[tmp_month].shape)

    dfc_norm = {}
    for df in dfc:
        dfc_norm[df] = get_row_based_norm(dfc[df])
    
    return dfc, dfc_norm

# %%
'''
    Fit the MDS algorithm to the distance matrix and plot the results
'''

def plot_MDS(m_norm, month, category):
      
    m = 1 - m_norm.values

    print(m.shape)
    feature_names = m_norm.index

    mds_model = manifold.MDS(n_components=2, random_state=1, dissimilarity='precomputed') # dissimilarity='precomputed'
    mds_coords = mds_model.fit_transform(m)

    # make directory for pics
    pic_path = os.path.join(parent_dir, 'Pics_MDS')
    if not os.path.exists(pic_path):
        os.mkdir(pic_path)
  
    with PdfPages('{}/MDS_similarity_graph_{}_{}.pdf'.format(pic_path, category, month)) as pdf:

        # plot the figure
        fig = plt.figure(figsize=(15,10))
        plt.scatter(mds_coords[:, 0], mds_coords[:, 1], 
                   facecolors='red', edgecolors='black') # points color
        labels = feature_names
        for label, x, y in zip(labels, mds_coords[:, 0], mds_coords[:, 1]):
            plt.annotate(label, (x, y), xycoords = 'data')
        # plt.xlabel('')
        plt.title('{} - {}: two-dimensional map from MDS algorithm'.format(month.upper(), category.capitalize()))
        pdf.savefig(fig)
        plt.show()
        plt.close()

        # scree plot
        mds_m = {}
        mds_c = {}
        for i in range(1, 16):
            mds_m[i] = manifold.MDS(n_components=i, random_state=1, dissimilarity='precomputed') # dissimilarity='precomputed'
            mds_c[i] = mds_m[i].fit_transform(m)

        mds_stress_list = [model.stress_ for k, model in mds_m.items()]

        fig = plt.figure()
        plt.plot(range(1, 16), mds_stress_list)
        plt.xlabel('Number of dimensions')
        plt.ylabel('Stress')
        plt.title('Scree plot of stress by number of dimensions')

        for i, stress in enumerate(mds_stress_list):
            plt.annotate(round(stress, 1), (i+0.3, stress))
        pdf.savefig(fig)
        plt.show()
        plt.close()

# %% [markdown]
# ## Restaurant

# %%
category = 'restaurant'

dfc_restaurant,\
dfc_norm_restaurant = get_dfc_norm(category)
# Out:
# Jul (29, 29)
# Aug (29, 29)
# Oct (32, 32)

# %%
for month, df in dfc_norm_restaurant.items():
    plot_MDS(df, month, category)
# Out:
# (29, 29)
# (29, 29)
# (32, 32)

# %% [markdown]
# ## Grocery

# %%
category = 'grocery'

dfc_grocery,\
dfc_norm_grocery = get_dfc_norm(category)
# Out:
# Jul (33, 33)
# Aug (33, 33)
# Oct (33, 33)

# %%
for month, df in dfc_norm_grocery.items():
    plot_MDS(df, month, category)
# Out:
# (33, 33)
# (33, 33)
# (33, 33)

# %% [markdown]
# ## Classical MDS algorithm
#
# Suppose a distance matrix $D$ approximates the inter-point distances of a configuration of points $X$ in a space of low dimensionality $p$ (usually $p = 1, 2, 3$). That is, the elements of $D$, denoted $d_{ij}$, may be calculated from $X$ using the following formula:
# $$
# d_{ij} = \sqrt{\sum_{k=1}^p (x_{ik} - x_{jk})^2}
# $$
#
# The steps in the classical MDS algorithm are as follows:
# 1. From $D$ calculate $A = \{ - \frac{1}{2} d_{ij}^2 \}$.
# 2. From $A$ calculate $B = \{ a_{ij} - a_{i.} - a{.j} + a{..} \}$, where $a_{i.}$ is the average of all $a_{ij}$ across $j$.
# 3. Find the $p$ largest eigenvalues $\lambda_1 > \lambda_2 > \dots > \lambda_p$ of $B$ and corresponding eigenvectors $L = ( L_{(1)}, L_{(2)}, \dots, L_{(p)} )$ which are normalized so that $L^T_{(i)} L_{(i)} = \lambda_i$. (We are assuming that $p$ is selected so that the eigenvalues are all relatively large and positive.)
# 4. The coordinates of the objects are the rows of $L$.
#
# The classical solution is optimal in the least-square sense.
# That is, when a direct solution is possible (when D is truly a Euclidean distance matrix rather than the dissimilarity matrix), the solution $L$, minimizes the sum of squared difference between the actual $d_{ij}$'s (elements of $D$) and the $\hat{d_{ij}}$'s based on $L$.
# Another way of saying this is that it minimizes the value of $stress$.

# %%
def cmdscale(D):
    """                                                                                       
    Classical multidimensional scaling (MDS)                                                  
                                                                                               
    Parameters                                                                                
    ----------                                                                                
    D : (n, n) array                                                                          
        Symmetric distance matrix.                                                            
                                                                                               
    Returns                                                                                   
    -------                                                                                   
    Y : (n, p) array                                                                          
        Configuration matrix. Each column represents a dimension. Only the                    
        p dimensions corresponding to positive eigenvalues of B are returned.                 
        Note that each dimension is only determined up to an overall sign,                    
        corresponding to a reflection.                                                        
                                                                                               
    e : (n,) array                                                                            
        Eigenvalues of B.                                                                     
                                                                                               
    """
    # Number of points                                                                        
    n = len(D)
 
    # Centering matrix                                                                        
    H = np.eye(n) - np.ones((n, n))/n
 
    # YY^T                                                                                    
    B = -H.dot(D**2).dot(H)/2
 
    # Diagonalize                                                                             
    evals, evecs = np.linalg.eigh(B)
 
    # Sort by eigenvalue in descending order                                                  
    idx   = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:,idx]
 
    # Compute the coordinates using positive-eigenvalued components only                      
    w, = np.where(evals > 0)
    L  = np.diag(np.sqrt(evals[w]))
    V  = evecs[:,w]
    Y  = V.dot(L)
 
    return Y, evals

# %% [markdown]
# ## Graph Visualization: similarity matrix

# %%
import networkx as nx

# %%
'''
    category: [restaurant, grocery]
    m: similarity matrix
        - sim_mat_restaurant
        - sim_mat_grocery
    
'''

def plot_similarity_graph(m, filename, category, day):
    
    edgeList = {}
    edgeList['node1'] = []
    edgeList['node2'] = []
    edgeList['distance'] = []

    for i in range(m.shape[0]):
        for j in range(i+1, m.shape[0]):
            edgeList['node1'].append(m.index[i])
            edgeList['node2'].append(m.columns[j])
            edgeList['distance'].append(m.iloc[i, j])
    edgeList = pd.DataFrame(edgeList)

    # Create empty graph
    G = nx.Graph()

    # Add nodes
    for f in m.index:
        G.add_node(str(f))

    # Add edges and edge attributes
    for i, elrow in edgeList.iterrows():
        G.add_weighted_edges_from([[str(elrow[0]), str(elrow[1]),elrow[2]]])

    pos = nx.spring_layout(G, weight='weight')

    # G.edges(data=True)
    
    '''
        Network graph: WITH edges
    '''

    pic_path = os.path.join(parent_dir, 'Pic_{}'.format(filename))
    if not os.path.exists(pic_path):
        os.mkdir(pic_path)

    plt.figure(figsize=(80, 80))
    nx.draw(G, pos=pos, with_labels=True, node_color = 'yellowgreen', 
           edge_color = 'lightgray', font_size = 50, node_size = 2500) # width=5, 
    plt.savefig('{}/{}_similarity_graph_{}.png'.format(pic_path, category, day))
#     plt.show()
    plt.close()

# %%
'''
    category: [restaurant, grocery]
    m: similarity matrix
        - sim_mat_restaurant
        - sim_mat_grocery
    
'''

'''
    category: [restaurant, grocery]
    m: similarity matrix
        - sim_mat_restaurant
        - sim_mat_grocery
    
'''

def plot_similarity_graph_pdf(tmp_path, category, dates):


    with PdfPages('{}/all_similarity_graph_{}.pdf'.format(tmp_path, category)) as pdf:
    
        m = pd.read_csv('{}/sim_mat_{}_all.csv'.format(tmp_path, category), index_col=0)

        edgeList = {}
        edgeList['node1'] = []
        edgeList['node2'] = []
        edgeList['distance'] = []

        for i in range(m.shape[0]):
            for j in range(i+1, m.shape[0]):
                edgeList['node1'].append(m.index[i])
                edgeList['node2'].append(m.columns[j])
                edgeList['distance'].append(m.iloc[i, j])
        edgeList = pd.DataFrame(edgeList)

        # Create empty graph
        G = nx.Graph()

        # Add nodes
        for f in m.index:
            G.add_node(str(f))

        # Add edges and edge attributes
        for i, elrow in edgeList.iterrows():
            G.add_weighted_edges_from([[str(elrow[0]), str(elrow[1]),elrow[2]]])

        pos = nx.spring_layout(G, weight='weight')

        # G.edges(data=True)

        '''
            Network graph: WITH edges
        '''
        fig = plt.figure(figsize = (80, 80))
        nx.draw(G, pos=pos, with_labels=True, node_color = 'yellowgreen', 
               edge_color = 'lightgray', font_size = 50, node_size = 2500) # width=5, 
#         txt = '{}-{}: Similarity graph of {}'.format(dates[0], dates[-1], category)
#         plt.text(0.05, 0.95, txt, transform=fig.transFigure, size = 60)
        pdf.savefig(fig)
        plt.close()
